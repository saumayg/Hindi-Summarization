# %%
import re
import pandas as pd
from indicnlp.tokenize import sentence_tokenize
from transformers import AutoConfig, AutoTokenizer, AutoModelForTokenClassification, pipeline

# %%
# df = pd.read_json("../Datasets/Hindi_summarization/XLSum/hindi_train.jsonl", lines = True)
df = pd.read_csv("Extractive_summ.csv")

# %%
df
# Out:
#                        Id                                            Heading  \
# 0      hindi_2023_train_4  डाइनिंग टेबल पर कुकर-कड़ाही न सजाएं, चीन के खा...
# 1     hindi_2023_train_29  CTI ने वित्तमंत्री को लेटर लिखकर कहा- एक्स्ट्र...
# 2     hindi_2023_train_40  किसी देश की सरहद जीतना मकसद नहीं, पड़ोसी देशों...
# 3     hindi_2023_train_46     16 अगस्त तक करें अप्लाई, 44 पदों पर होगी भर्ती
# 4     hindi_2023_train_49  ​​​​​​​फुल चार्ज पर 115KM की रेंज का दावा, 3 अ...
# ...                   ...                                                ...
# 3510     hindi_2022_11361  यूपी: भ्रामक खबर फैलाने के आरोप में तीन पत्रका...
# 3511     hindi_2022_11362  हेलीकॉप्टर क्रैश होने से ठीक पहले का आखिरी VID...
# 3512     hindi_2022_11363  MSP पर प्रधानमंत्री ने कमेटी बनाई, पराली जलाना...
# 3513     hindi_2022_11364  योगी सरकार ने 9 गेस्ट हाउस का नाम नदियों, धार्...
# 3514     hindi_2022_11367  अखिलेश के करीबी पम्पी जैन के ठिकानों से क्या-क...
#
# ...

# %%
text = df['Article'][0]
# text = df['text'][163]
# text = df['text'][0]
# text = "1. वेनेज़ुएला: 1 रुपए 36 पैसे 2. सऊदी अरब: 15 रुपए 59 पैसे 3. ईरान: 21 रुपए 68 पैसे 4. अमरीकाः 39 रुपए 40 पैसे समाप्त 5. पाकिस्तान: 49 रुपए 47 पैसे 6. भारतः 59 रुपए 99 पैसे (दिल्ली) 65 रुपए 59 पैसे (लखनऊ) 7. नेपाल: 58 रुपए 95 पैसे 8. श्रीलंका: 60 रुपए 31 पैसे 9. चीनः 60 रुपए 99 पैसे 10. बांग्लादेश: 80 रुपए 64 पैसे 11. ब्रिटेनः 98 रुपए 26 पैसे 12. हांगकांग: 121 रुपए 97 पैसे (एक डॉलर: 67.76 रुपए) (सौजन्य: www.globalpetrolprice.com) (बीबीसी हिंदी के एंड्रॉएड ऐप के लिए आप यहां क्लिक कर सकते हैं. आप हमें फ़ेसबुक और ट्विटर पर फ़ॉलो भी कर सकते हैं.)"
# text = "खेल में उसी पल उसी समय निर्णय लेना होता है और ज़िंदगी में बहुत सारी चीज़ें ऐसी हैं जिसमें आपको उसी वक़्त निर्णय लेना होता है. इसीलिए बाद में पछतावा नहीं करना चाहिए. क्योंकि तब का समय और तब के हालात अलग होते हैं और वो समय अलग होता है जब बाद में आपको सोचने का मौका मिलता है. जो मैं करूँगा अच्छे के लिए करूँगा. जो मैं करूँगा अपने दिल से करूँगा. जो मैं करूँगा उसमें यही चाहूँगा कि भारतीय क्रिकेट टीम जीते. मैं यह भी कहूँगा कि टीवी की तरह खेल में कोई रीटेक नहीं होते. अभी टीवी में काम करते हुए रीटेक मिलते ह
# "स्वाद खाने की बुनियाद है। लेकिन अगर खाना सुंदर तरीके से परोसा गया है तो, उसका जायका और बढ़ जाता है। खाना बनाने-खिलाने के शौकीन लोग इस खूबसूरती का खाना पकाने से लेकर उसे प्लेट में परोसे जाने तक हर स्टेज पर ध्यान रखते हैं।\nआज ‘फुरसत का रविवार’ है। आप या तो किसी मेहमान की मेजबानी में व्यस्त होंगे या किसी के घर दावत पर जाने की तैयारी में लगे होंगे। मेहमान खाने की टेबल पर जब पहुंचे तो खाना इतने सलीके से सजा दिखे, जिसे देखते ही भूख खुल जाए। \nबहरहाल, इंसान ने जब से भोजन पकाना शुरू किया तब से इसे करीने से परोसने का सिलसिला भी शुरू हुआ। लेकिन भोजन परोसने की कला का दस्तावेजीकरण 1600 में फ्रांस से शुरू हुआ।\nफ्रांस के सम्राट लुई-14 ने अपने रसोइयों को डाइनिंग टेबल पर भोजन को खूबसूरत तरीके से पेश करने के आदेश दिए थे। यूरोप में तब से फूड डेकोरेशन पर जोर दिया जाने लगा। 19वीं शताब्दी में फ्रांसीसी शेफ ऑगस्टे एस्कॉफ़ियर ने खाने को सलीके से परोसने की कला को नया आयाम दिया।\nमसलन दम आलू बनाने के लिए मीडियम साइज आलू लिए जाते हैं। उबालने के बाद आलू को एक समान आंच पर डीप फ्राई किया जाता है। आलू दम तैयार
# ...

# %%
text = text.lower()
with open('stopwords-hi.txt', 'r', encoding='utf-8') as file:
    stop_words = set(file.read().split())

# %%
text
# Out:
# "स्वाद खाने की बुनियाद है। लेकिन अगर खाना सुंदर तरीके से परोसा गया है तो, उसका जायका और बढ़ जाता है। खाना बनाने-खिलाने के शौकीन लोग इस खूबसूरती का खाना पकाने से लेकर उसे प्लेट में परोसे जाने तक हर स्टेज पर ध्यान रखते हैं।\nआज ‘फुरसत का रविवार’ है। आप या तो किसी मेहमान की मेजबानी में व्यस्त होंगे या किसी के घर दावत पर जाने की तैयारी में लगे होंगे। मेहमान खाने की टेबल पर जब पहुंचे तो खाना इतने सलीके से सजा दिखे, जिसे देखते ही भूख खुल जाए। \nबहरहाल, इंसान ने जब से भोजन पकाना शुरू किया तब से इसे करीने से परोसने का सिलसिला भी शुरू हुआ। लेकिन भोजन परोसने की कला का दस्तावेजीकरण 1600 में फ्रांस से शुरू हुआ।\nफ्रांस के सम्राट लुई-14 ने अपने रसोइयों को डाइनिंग टेबल पर भोजन को खूबसूरत तरीके से पेश करने के आदेश दिए थे। यूरोप में तब से फूड डेकोरेशन पर जोर दिया जाने लगा। 19वीं शताब्दी में फ्रांसीसी शेफ ऑगस्टे एस्कॉफ़ियर ने खाने को सलीके से परोसने की कला को नया आयाम दिया।\nमसलन दम आलू बनाने के लिए मीडियम साइज आलू लिए जाते हैं। उबालने के बाद आलू को एक समान आंच पर डीप फ्राई किया जाता है। आलू दम तैयार
# ...

# %%
text = re.sub(r'(?<=\d)\.|(?<=\S)\.(?=\S)|,|‘|’|\n|:|;|\"|\'|\(|\)|\{|\}|/|\\|\[|\]|-|_|\+|=|\*|&|^|%|\$|#|@|~|`|\|', '', text)
# text = re.sub(r'(?<![^\u0900-\u097F])[.।!?]|[^.।!?|\u0900-\u097F\s]+', '', text)
# First pattern: Retain periods, purnviram, question marks, and exclamation marks after Hindi characters
# retained_punctuation_pattern = r'(?<=[\u0900-\u097F])[.।!?]|[^ \u0900-\u097F]'

#     # Apply first pattern
# intermediate_text = re.sub(retained_punctuation_pattern, lambda m: m.group() if m.group() else '', text)

#     # Second pattern: Remove other punctuation not preceded by Hindi characters
# remove_punctuation_pattern = r'(?<![ \u0900-\u097F])[.,;\':!?"]'

#     # Apply second pattern
# processed_text = re.sub(remove_punctuation_pattern, '', intermediate_text)

# %%
text
# Out:
# 'स्वाद खाने की बुनियाद है। लेकिन अगर खाना सुंदर तरीके से परोसा गया है तो उसका जायका और बढ़ जाता है। खाना बनानेखिलाने के शौकीन लोग इस खूबसूरती का खाना पकाने से लेकर उसे प्लेट में परोसे जाने तक हर स्टेज पर ध्यान रखते हैं।आज फुरसत का रविवार है। आप या तो किसी मेहमान की मेजबानी में व्यस्त होंगे या किसी के घर दावत पर जाने की तैयारी में लगे होंगे। मेहमान खाने की टेबल पर जब पहुंचे तो खाना इतने सलीके से सजा दिखे जिसे देखते ही भूख खुल जाए। बहरहाल इंसान ने जब से भोजन पकाना शुरू किया तब से इसे करीने से परोसने का सिलसिला भी शुरू हुआ। लेकिन भोजन परोसने की कला का दस्तावेजीकरण 1600 में फ्रांस से शुरू हुआ।फ्रांस के सम्राट लुई14 ने अपने रसोइयों को डाइनिंग टेबल पर भोजन को खूबसूरत तरीके से पेश करने के आदेश दिए थे। यूरोप में तब से फूड डेकोरेशन पर जोर दिया जाने लगा। 19वीं शताब्दी में फ्रांसीसी शेफ ऑगस्टे एस्कॉफ़ियर ने खाने को सलीके से परोसने की कला को नया आयाम दिया।मसलन दम आलू बनाने के लिए मीडियम साइज आलू लिए जाते हैं। उबालने के बाद आलू को एक समान आंच पर डीप फ्राई किया जाता है। आलू दम तैयार होने के बाद उस
# ...

# %%
orig_sentences = sentence_tokenize.sentence_split(text, lang='hi')

# %%
orig_sentences
# Out:
# ['स्वाद खाने की बुनियाद है।',
#  'लेकिन अगर खाना सुंदर तरीके से परोसा गया है तो उसका जायका और बढ़ जाता है।',
#  'खाना बनानेखिलाने के शौकीन लोग इस खूबसूरती का खाना पकाने से लेकर उसे प्लेट में परोसे जाने तक हर स्टेज पर ध्यान रखते हैं।',
#  'आज फुरसत का रविवार है।',
#  'आप या तो किसी मेहमान की मेजबानी में व्यस्त होंगे या किसी के घर दावत पर जाने की तैयारी में लगे होंगे।',
#  'मेहमान खाने की टेबल पर जब पहुंचे तो खाना इतने सलीके से सजा दिखे जिसे देखते ही भूख खुल जाए।',
#  'बहरहाल इंसान ने जब से भोजन पकाना शुरू किया तब से इसे करीने से परोसने का सिलसिला भी शुरू हुआ।',
#  'लेकिन भोजन परोसने की कला का दस्तावेजीकरण 1600 में फ्रांस से शुरू हुआ।',
#  'फ्रांस के सम्राट लुई14 ने अपने रसोइयों को डाइनिंग टेबल पर भोजन को खूबसूरत तरीके से पेश करने के आदेश दिए थे।',
#  'यूरोप में तब से फूड डेकोरेशन पर जोर दिया जाने लगा।',
#  '19वीं शताब्दी में फ्रांसीसी शेफ ऑगस्टे एस्कॉफ़ियर ने खाने को सलीके से परोसने की कला को नया आयाम दिया।',
#  'मसलन दम आलू बनाने के लिए मीडियम साइज आलू लिए जाते हैं।',
# ...

# %%
len(orig_sentences)
# Out:
# 70

# %%
sentences = []
for sentence in orig_sentences:
    words  = re.split(r'\s+|(?<=[\u0900-\u097F])(?=[?.!])|(?<=[?.!])(?=[\u0900-\u097F])', sentence)
    words = [word for word in words if word not in stop_words and word.strip() != '']
    clean_sent = ''.join(word if word in ['.', '?', '!'] else word + ' ' for word in words).strip()
    sentences.append(clean_sent)
    print(clean_sent)
# Out:
# स्वाद खाने बुनियाद है।
# अगर खाना सुंदर तरीके परोसा उसका जायका बढ़ जाता है।
# खाना बनानेखिलाने शौकीन लोग खूबसूरती खाना पकाने लेकर प्लेट परोसे जाने हर स्टेज ध्यान रखते हैं।
# आज फुरसत रविवार है।
# मेहमान मेजबानी व्यस्त होंगे दावत जाने तैयारी लगे होंगे।
# मेहमान खाने टेबल पहुंचे खाना इतने सलीके सजा दिखे देखते भूख खुल जाए।
# बहरहाल इंसान भोजन पकाना शुरू करीने परोसने सिलसिला शुरू हुआ।
# भोजन परोसने कला दस्तावेजीकरण 1600 फ्रांस शुरू हुआ।
# फ्रांस सम्राट लुई14 रसोइयों डाइनिंग टेबल भोजन खूबसूरत तरीके पेश आदेश दिए थे।
# यूरोप फूड डेकोरेशन जोर जाने लगा।
# 19वीं शताब्दी फ्रांसीसी शेफ ऑगस्टे एस्कॉफ़ियर खाने सलीके परोसने कला नया आयाम दिया।
# मसलन दम आलू बनाने मीडियम साइज आलू जाते हैं।
# उबालने आलू समान आंच डीप फ्राई जाता है।
# आलू दम तैयार कटोरी हरी धनिया हरी मिर्च गार्निश थाली दाहिने तरफ रखकर परोसा जाता है।
# खाना परोसना बना दौलत नुमाइश ताकत प्रदर्शनयूरोप समय दौलत ताकत प्रदर्शन रईस लोग शाही दावत देते थे।
# बताया जाता रोमन मेजबान थाली खूबसूरत अपील बढ़ाने खाने कीमती धातुएं मिलाकर परोसते थे।
# ...

# %%
len(sentences)
# Out:
# 70

# %%
def sentence_embedding(sentence, model):
    words = sentence.split()
    embeddings = [model.get_word_vector(word) for word in words if word not in ['.', '\u0964', '?', '!']]
    if embeddings:
        return np.mean(embeddings, axis = 0)
    else:
        return np.zeros(model.get_dimension())

# %%
import fasttext
model_path = 'cc.hi.300.bin'
fasttext_model = fasttext.load_model(model_path)

# %%
import numpy as np
sentence_vectors = [sentence_embedding(sentence, fasttext_model) for sentence in sentences]

# %%
len(sentence_vectors[0])

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_matrix = np.zeros((len(sentences), len(sentences)))
for i in range(len(sentences)):
    for j in range(len(sentences)):
        if i != j:
            similarity_matrix[i][j] = cosine_similarity(sentence_vectors[i].reshape(1,300), sentence_vectors[j].reshape(1,300))[0,0]

# %%
hiner_config = AutoConfig.from_pretrained(hiner_model_name)
if hiner_config.model_type in {"bloom", "gpt2", "roberta"}:
    hiner_tokenizer = AutoTokenizer.from_pretrained(
        hiner_model_name,
        add_prefix_space=True,
    )
else:
    hiner_tokenizer = AutoTokenizer.from_pretrained(
        hiner_model_name,
        padding=False,
        truncation=True,
        model_max_length = 512,
    )
hiner_model = AutoModelForTokenClassification.from_pretrained(
    hiner_model_name,
    config=hiner_config,
)
ner_model_first = pipeline("ner", model=hiner_model, tokenizer=hiner_tokenizer, aggregation_strategy = "first")

# %%
import networkx as nx
nx_graph = nx.from_numpy_array(similarity_matrix)
scores = nx.pagerank(nx_graph)

# %%
len(orig_sentences)
# Out:
# 70

# %%
len(sentences)
# Out:
# 70

# %%
scores
# Out:
# {0: 0.013581106749534775,
#  1: 0.01659827211957084,
#  2: 0.017358842893287225,
#  3: 0.009610247259135023,
#  4: 0.014961400699601576,
#  5: 0.01642609051861542,
#  6: 0.015513874981867301,
#  7: 0.014192417031273798,
#  8: 0.016205642323991434,
#  9: 0.014347695323061255,
#  10: 0.01551540181398768,
#  11: 0.01191893385663005,
#  12: 0.01173994190914017,
#  13: 0.01436094958034607,
#  14: 0.015945245711581593,
#  15: 0.016883313207405055,
#  16: 0.014516577703822817,
#  17: 0.013477591765220186,
#  18: 0.015751262898005037,
#  19: 0.015943891008450582,
#  20: 0.015807391483044306,
#  21: 0.015062434805279898,
#  22: 0.01360257825804069,
#  23: 0.011962372717299111,
#  24: 0.01274290190630644,
#  25: 0.014081165587333957,
#  26: 0.008639832583637621,
#  27: 0.012328684799536022,
#  28: 0.013330938423769114,
#  29: 0.014424843424947617,
#  30: 0.01544667907535702,
#  31: 0.013432034265142724,
#  32: 0.013908543532494443,
#  33: 0.0157400822043147,
#  34: 0.01515509857589675,
# ...

# %%
ranked_sentences = sorted(((scores[i],s) for i,s in enumerate(orig_sentences)), reverse=True)

# %%
ranked_sentences
# Out:
# [(0.017358842893287225,
#   'खाना बनानेखिलाने के शौकीन लोग इस खूबसूरती का खाना पकाने से लेकर उसे प्लेट में परोसे जाने तक हर स्टेज पर ध्यान रखते हैं।'),
#  (0.016972654200887775,
#   'हालांकि बेहतर यह रहेगा कि खाते समय ही रोटी बनाकर गर्मगर्म छोटे प्लेट में तुरंत परोसी जाए।'),
#  (0.016883313207405055,
#   'बताया जाता है कि रोमन मेजबान थाली की खूबसूरत अपील बढ़ाने के लिए खाने में कीमती धातुएं मिलाकर परोसते थे।'),
#  (0.016871456952877714,
#   'प्लेटिंगः प्लेट में हर चीज परफेक्ट तरीके से सर्व करें \nकुकिंग में स्वादिष्ट खाना बनाने पर जितना जोर होता है उतना ही फूड सर्व करने के सलीके पर भी जोर दिया जाने लगा है।'),
#  (0.01659827211957084,
#   'लेकिन अगर खाना सुंदर तरीके से परोसा गया है तो उसका जायका और बढ़ जाता है।'),
#  (0.016495181613903488,
#   'परोसने वाली कलछी और बड़ा चम्मच अलग होना चाहिए\nखाना बनाने और सर्व करने वाले बर्तन अलग होने चाहिए।'),
#  (0.016471136742346754,
#   'खाना परोसने के तौरतरीके पर फोकस बढ़ा\nअब भी दावत मेजबान की निजी और सामाजिक हैसियत बताती है।'),
# ...
